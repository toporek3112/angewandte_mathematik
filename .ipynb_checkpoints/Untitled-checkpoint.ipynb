# %% [markdown]
# Veranschaulichung eines Vektors im R2

# %% [markdown]
# a) Vector (-3, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and an axis
fig, ax = plt.subplots()

# A sample vector (x_position, y_position, x_direction, y_direction)
v_x = np.array([-3, 1])
#v_y = np.array([-4, 2])

# Using quiver to plot the vector
ax.quiver(*v_x, scale=1, scale_units='xy', angles='xy')
#ax.quiver(*v_y, scale=1, scale_units='xy', angles='xy')

# Setting the limits and labels
ax.set_xlim(-4, 1)
ax.set_ylim(0, 2)
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Showing the plot
plt.grid()
plt.show()

sp = 0
for i in range(len(v_x)):
    sp += v_x[i] * v_y[i]

print(f'Standartskalarproduct: {sp}')
# Out:
# Standartskalarproduct: 14

# %% [markdown]
# b) als Vektor P-->Q, wobei P = (2, 1). Wie lauten die Koordinaten von Q?

# %%
import matplotlib.pyplot as plt
import numpy as np

def get_point(vector, fp, sp):
    if (fp == null):
        
    fs = s - f
    

# Defining the origin and vectors
origin = np.array([0, 0])
vector_x = np.array([-3, 1])
point_p = np.array([2, 1])
vector_pq = vector_x
point_q = point_p + vector_pq


# Creating the plot
plt.figure(figsize=(8, 6))
plt.quiver(*origin, *vector_a, color='r', scale=1, scale_units='xy', angles='xy', label='Ortsvektor OA (-3, 1)')
plt.quiver(*point_p, *vector_pq, color='b', scale=1, scale_units='xy', angles='xy', label='Vektor PQ (-3, 1) von P (2, 1)')

# Marking points
plt.scatter(*origin, color='black', label='Origin (0,0)')
plt.scatter(*point_p, color='green', label='Point P (2,1)')
plt.scatter(*point_q, color='purple', label='Point Q (-1,2)')

# Adding labels, grid, legend, and setting limits
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.legend()
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.title('Veranschaulichung des Vektors (-3, 1) im R2')

# Displaying the plot
plt.show()
